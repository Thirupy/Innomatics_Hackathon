# %% [markdown]
# # This Innomatics Research Labs Internship Hackathon

# %%
import pandas as pd
links=pd.read_csv('./links.csv')
movies=pd.read_csv('./movies.csv')
tags=pd.read_csv('./tags.csv')
ratings=pd.read_csv('./ratings.csv')
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# # 1) How many ".csv" files are available in tha dataset

# %% [markdown]
# ## 4

# %% [markdown]
# # 2) What is the shape of "movies.csv"?

# %%
movies.shape
# Out:
# (9742, 3)

# %% [markdown]
# # 3) What is the shape of "ratings.csv"?

# %%
ratings.shape
# Out:
# (100836, 4)

# %% [markdown]
# # 4) How many unique "userId" are available in "ratings.csv"?

# %%
len(ratings['userId'].unique())
# Out:
# 610

# %% [markdown]
# # 5) Which movie has recieved maximum number of user ratings?

# %%
ratings_count = ratings.groupby('movieId').size()

sorted_ratings_count = ratings_count.sort_values(ascending=False)


most_rated_movie = sorted_ratings_count.idxmax()
max_ratings = sorted_ratings_count.max()

# %%
sorted_ratings_count.idxmax()
# Out:
# 356

# %% [markdown]
# # 6) Select all the correct tags submitted by users to "Matrix, The (1999)" movie?

# %%
mat_id=movies[movies['title']=='Matrix, The (1999)']['movieId'].values[0]
mat_id
# Out:
# 2571

# %%
tags[tags['movieId']==mat_id]
# Out:
#       userId  movieId                 tag   timestamp
# 815      424     2571        martial arts  1457842912
# 816      424     2571              sci-fi  1457842899
# 1646     474     2571  alternate universe  1137204991
# 2794     537     2571          philosophy  1424141098
# 2795     537     2571    post apocalyptic  1424141101

# %% [markdown]
# # 7) What is the average user rating for movie named "Terminator 2: Judgment Day (1991)"?

# %%
movies[movies['title']=='Terminator 2: Judgment Day (1991)']
# Out:
#      movieId                              title         genres
# 507      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi

# %%
ratings[ratings['movieId']==589]['rating'].mean()
# Out:
# 3.970982142857143

# %% [markdown]
# # 8) How does the data distribution of user ratings for "Fight Club (1999)" movie looks like?

# %%
movies[movies['title']=='Fight Club (1999)']
# Out:
#       movieId              title                       genres
# 2226     2959  Fight Club (1999)  Action|Crime|Drama|Thriller

# %%
a=ratings[ratings['movieId']==2959]['rating'].tolist()
a
# Out:
# [5.0,
#  2.0,
#  0.5,
#  2.5,
#  3.5,
#  4.5,
#  4.5,
#  5.0,
#  2.0,
#  3.5,
#  3.5,
#  4.0,
#  4.0,
#  3.0,
#  5.0,
#  2.0,
#  3.0,
#  4.5,
#  5.0,
#  5.0,
#  4.5,
#  4.5,
#  5.0,
#  4.5,
#  2.5,
#  4.5,
#  5.0,
#  3.5,
#  4.5,
#  5.0,
#  5.0,
#  5.0,
#  4.5,
#  5.0,
#  5.0,
#  4.5,
#  5.0,
#  4.0,
#  4.0,
#  5.0,
#  3.0,
#  5.0,
#  4.0,
#  5.0,
#  0.5,
#  4.0,
#  5.0,
#  3.0,
#  4.5,
#  4.5,
#  4.0,
#  4.5,
#  4.5,
#  5.0,
#  3.0,
#  4.0,
#  4.0,
#  3.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  4.5,
#  5.0,
#  4.5,
#  4.5,
#  4.5,
#  1.5,
#  5.0,
#  3.5,
#  4.0,
#  5.0,
#  3.0,
#  4.5,
#  4.0,
#  5.0,
#  3.0,
#  4.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  5.0,
#  4.0,
#  5.0,
#  5.0,
#  5.0,
#  3.5,
#  4.5,
#  5.0,
#  4.0,
#  3.5,
#  3.0,
#  2.0,
#  4.5,
#  5.0,
#  5.0,
#  4.5,
#  4.5,
#  4.0,
#  0.5,
#  5.0,
#  5.0,
#  4.0,
#  4.0,
#  4.0,
#  5.0,
#  4.0,
#  4.0,
#  4.5,
#  3.5,
#  4.5,
#  4.5,
#  4.0,
#  4.0,
#  5.0,
#  3.5,
#  5.0,
#  4.0,
#  5.0,
#  4.5,
#  5.0,
#  4.5,
#  4.5,
#  4.5,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

data = a

plt.hist(data, bins=30, density=True, alpha=0.6, color='g')
mu, std = stats.norm.fit(data)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.show()

# %% [markdown]
# # it is left Skewed Distribution

# %% [markdown]
# # 9) Which movie is the most popular based on average user ratings?

# %%
movies_path = 'movies.csv'
ratings_path = 'ratings.csv'

movies_df = movies
ratings_df = ratings

grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'count'),
    rating_mean=('rating', 'mean')
).reset_index()
merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')


filtered_movies = merged_df[merged_df['rating_count'] > 50]

most_popular_movie = filtered_movies.loc[filtered_movies['rating_mean'].idxmax()]
most_popular_movie[['title', 'rating_mean']]
# Out:
# title          Shawshank Redemption, The (1994)
# rating_mean                            4.429022
# Name: 277, dtype: object

# %% [markdown]
# # 10) Select all the correct options which comes under top 5 popular movies based on number of user ratings

# %%
movies_path = 'movies.csv'
ratings_path = 'ratings.csv'
movies_df = pd.read_csv(movies_path)
ratings_df = pd.read_csv(ratings_path)

grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'count'),
    rating_mean=('rating', 'mean')
).reset_index()
merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')
filtered_movies = merged_df[merged_df['rating_count'] > 50]
top_5_movies = filtered_movies.nlargest(5, 'rating_count')
top_5_movies[['title', 'rating_count']]
# Out:
#                                  title  rating_count
# 314                Forrest Gump (1994)           329
# 277   Shawshank Redemption, The (1994)           317
# 257                Pulp Fiction (1994)           307
# 510   Silence of the Lambs, The (1991)           279
# 1938                Matrix, The (1999)           278

# %% [markdown]
# # 11) Which Sci-Fi movie is "third most popular" based on the number of user ratings?

# %%
movies_df = pd.read_csv(movies_path)
ratings_df = pd.read_csv(ratings_path)
grouped_ratings = ratings_df.groupby('movieId').agg(
    rating_count=('rating', 'count'),
    rating_mean=('rating', 'mean')
).reset_index()

merged_df = pd.merge(movies_df, grouped_ratings, on='movieId', how='inner')

filtered_movies = merged_df[merged_df['rating_count'] > 50]
sci_fi_movies = filtered_movies[filtered_movies['genres'].str.contains('Sci-Fi')]
top_sci_fi_movies = sci_fi_movies.nlargest(3, 'rating_count')
third_most_popular_sci_fi = top_sci_fi_movies.iloc[2]

third_most_popular_sci_fi[['title', 'rating_count']]
# Out:
# title           Jurassic Park (1993)
# rating_count                     238
# Name: 418, dtype: object

# %% [markdown]
# # 12) Mention the movieId of the movie which has the highest IMDB rating

# %%
rating_counts = ratings.groupby('movieId').size()

movies_with_50_plus_ratings = rating_counts[rating_counts > 50].index.tolist()

# %%
rating_counts
# Out:
# movieId
# 1         215
# 2         110
# 3          52
# 4           7
# 5          49
#          ...
# 193581      1
# 193583      1
# 193585      1
# 193587      1
# 193609      1
# Length: 9724, dtype: int64

# %%
movies_with_50_plus_ratings
# Out:
# [1,
#  2,
#  3,
#  6,
#  7,
#  10,
#  11,
#  16,
#  17,
#  19,
#  21,
#  25,
#  32,
#  34,
#  36,
#  39,
#  47,
#  48,
#  50,
#  62,
#  70,
#  95,
#  104,
#  110,
#  111,
#  141,
#  145,
#  150,
#  153,
#  158,
#  160,
#  161,
#  163,
#  165,
#  168,
#  172,
#  173,
#  185,
#  208,
#  223,
#  225,
#  231,
#  235,
#  253,
#  260,
#  266,
#  288,
#  292,
#  293,
#  296,
#  300,
#  316,
#  317,
#  318,
#  329,
#  337,
#  339,
#  344,
#  349,
#  350,
#  353,
#  356,
#  357,
#  364,
#  367,
#  368,
#  370,
#  377,
#  380,
#  410,
#  420,
#  432,
#  434,
#  435,
#  440,
#  442,
#  454,
#  457,
#  466,
#  474,
#  480,
#  485,
#  500,
#  508,
#  509,
#  520,
#  527,
#  539,
#  541,
#  551,
#  552,
#  553,
#  555,
#  586,
#  587,
#  588,
#  589,
#  590,
#  592,
#  593,
#  594,
#  595,
#  596,
#  597,
#  608,
#  648,
#  653,
#  673,
#  708,
#  733,
#  736,
#  750,
#  778,
#  780,
#  784,
#  786,
#  788,
#  858,
#  903,
#  904,
#  908,
#  912,
#  919,
#  923,
#  924,
#  953,
#  1028,
#  1035,
# ...

# %%
new_data=links[links['movieId'].isin(movies_with_50_plus_ratings)]

# %%
new_data.to_csv('movies_with_50_plus_ratings.csv')

# %% [markdown]
# ## Web Scrapping

# %%
import pandas as pd

a=pd.read_csv("./movies_with_50_plus_ratings.csv")
import nest_asyncio
nest_asyncio.apply()

import aiohttp
import asyncio
from bs4 import BeautifulSoup
from tqdm import tqdm

async def fetch_imdb_rating(session, imdb_id):
    id = str(int(imdb_id))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    url = f"https://www.imdb.com/title/tt{new_id}/"
    headers = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'My Cool Movie Rating App',
        'Accept-Encoding': 'gzip, deflate, br'
    }

    retries = 10
    for attempt in range(retries):
        try:
            async with session.get(url, headers=headers) as response:
                if response.status == 200:
                    html_content = await response.text()
                    soup = BeautifulSoup(html_content, 'html.parser')
                    imdb_rating = soup.find('span', attrs={'class': 'sc-eb51e184-1 ljxVSS'})
                    return imdb_rating.text if imdb_rating else None
                else:
                    return None
        except (aiohttp.ClientError, aiohttp.ClientConnectionError):
            print(f"Attempt {attempt + 1}/{retries}: Connection error. Retrying...")
            await asyncio.sleep(5) 

    return None


async def loop_data_async(imdb_ids):
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_imdb_rating(session, imdb_id) for imdb_id in imdb_ids]
        imdb_ratings = await asyncio.gather(*tasks)
        for i, rating in enumerate(imdb_ratings):
            if rating and (i + 1) % 10 == 0:
                print(f"Scraped rating for movie {i + 1}: {rating}")
        return imdb_ratings


def loop_data():
    imdb_ids = a["imdbId"]
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    try:
        return loop.run_until_complete(loop_data_async(imdb_ids))
    finally:
        loop.close()


a["Imdb_ratings"] = loop_data()
a.head()
# Out:
# Scraped rating for movie 10: 6.4
# Scraped rating for movie 20: 7.3
# Scraped rating for movie 30: 6.2
# Scraped rating for movie 40: 7.7
# Scraped rating for movie 50: 8.9
# Scraped rating for movie 60: 6.7
# Scraped rating for movie 70: 6.8
# Scraped rating for movie 80: 7.2
# Scraped rating for movie 90: 7.9
# Scraped rating for movie 100: 8.6
# Scraped rating for movie 110: 7.4
# Scraped rating for movie 120: 8.5
# Scraped rating for movie 130: 7.8
# Scraped rating for movie 140: 8.7
# Scraped rating for movie 150: 8.4
# Scraped rating for movie 160: 8.0
# Scraped rating for movie 170: 8.1
# Scraped rating for movie 180: 7.7
# Scraped rating for movie 190: 7.3
# Scraped rating for movie 200: 8.2
# Scraped rating for movie 210: 8.1
# Scraped rating for movie 220: 7.7
# Scraped rating for movie 230: 7.5
# Scraped rating for movie 240: 7.3
# Scraped rating for movie 250: 7.3
# Scraped rating for movie 260: 7.7
# Scraped rating for movie 270: 8.3
# Scraped rating for movie 280: 7.3
# ...

# %%
a.to_csv('movies_with_50_plus_ratings_scrapped.csv')

# %%
a[a['Imdb_ratings']==a['Imdb_ratings'].max()]
# Out:
#     Unnamed: 0  movieId  imdbId  tmdbId Imdb_ratings
# 53         277      318  111161   278.0          9.3

# %% [markdown]
# # 13) Mention the movieId of the "Sci-Fi" movie which has the highest IMDB rating

# %%
df = movies

df['genres'] = df['genres'].str.split('|')
df_exploded = df.explode('genres').reset_index(drop=True)


df_exploded
# Out:
#        movieId                                title     genres
# 0            1                     Toy Story (1995)  Adventure
# 1            1                     Toy Story (1995)  Animation
# 2            1                     Toy Story (1995)   Children
# 3            1                     Toy Story (1995)     Comedy
# 4            1                     Toy Story (1995)    Fantasy
# ...        ...                                  ...        ...
# 22079   193583         No Game No Life: Zero (2017)    Fantasy
# 22080   193585                         Flint (2017)      Drama
# 22081   193587  Bungo Stray Dogs: Dead Apple (2018)     Action
# 22082   193587  Bungo Stray Dogs: Dead Apple (2018)  Animation
# 22083   193609  Andrew Dice Clay: Dice Rules (1991)     Comedy
#
# [22084 rows x 3 columns]

# %%
SciFi_only=df_exploded[df_exploded['genres']=='Sci-Fi']
SciFi_only
# Out:
#        movieId                                              title  genres
# 60          24                                      Powder (1995)  Sci-Fi
# 72          29  City of Lost Children, The (Cité des enfants p...  Sci-Fi
# 77          32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Sci-Fi
# 138         66          Lawnmower Man 2: Beyond Cyberspace (1996)  Sci-Fi
# 157         76                                   Screamers (1995)  Sci-Fi
# ...        ...                                                ...     ...
# 22027   188301                        Ant-Man and the Wasp (2018)  Sci-Fi
# 22046   189547                                Iron Soldier (2010)  Sci-Fi
# 22050   190183                           The Darkest Minds (2018)  Sci-Fi
# 22062   191005                                     Gintama (2017)  Sci-Fi
# 22066   193565                          Gintama: The Movie (2010)  Sci-Fi
#
# [980 rows x 3 columns]

# %%
SciFi_id=set(SciFi_only['movieId'].tolist())

# %%
SciFi_data=links[links['movieId'].isin(SciFi_id)]

# %%
SciFi_data
# Out:
#       movieId   imdbId    tmdbId
# 23         24   114168   12665.0
# 28         29   112682     902.0
# 31         32   114746      63.0
# 59         66   116839   11525.0
# 68         76   114367    9102.0
# ...       ...      ...       ...
# 9713   188301  5095030  363088.0
# 9722   189547  1665744  111196.0
# 9724   190183  4073790  445651.0
# 9731   191005  5805470  432985.0
# 9732   193565  1636780   71172.0
#
# [980 rows x 3 columns]

# %% [markdown]
# ## Web Scrapping for Sci-Fi Movies

# %%
import pandas as pd

a=SciFi_data
import nest_asyncio
nest_asyncio.apply()

import aiohttp
import asyncio
from bs4 import BeautifulSoup
from tqdm import tqdm

async def fetch_imdb_rating(session, imdb_id):
    id = str(int(imdb_id))
    n_zeroes = 7 - len(id)
    new_id = "0" * n_zeroes + id
    url = f"https://www.imdb.com/title/tt{new_id}/"
    headers = {
        'Content-Type': 'text/html; charset=UTF-8',
        'User-Agent': 'My Cool Movie Rating App',
        'Accept-Encoding': 'gzip, deflate, br'
    }

    retries = 10
    for attempt in range(retries):
        try:
            async with session.get(url, headers=headers) as response:
                if response.status == 200:
                    html_content = await response.text()
                    soup = BeautifulSoup(html_content, 'html.parser')
                    imdb_rating = soup.find('span', attrs={'class': 'sc-eb51e184-1 ljxVSS'})
                    return imdb_rating.text if imdb_rating else None
                else:
                    return None
        except (aiohttp.ClientError, aiohttp.ClientConnectionError):
            print(f"Attempt {attempt + 1}/{retries}: Connection error. Retrying...")
            await asyncio.sleep(5) 

    return None


async def loop_data_async(imdb_ids):
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_imdb_rating(session, imdb_id) for imdb_id in imdb_ids]
        imdb_ratings = await asyncio.gather(*tasks)
        for i, rating in enumerate(imdb_ratings):
            if rating and (i + 1) % 10 == 0:
                print(f"Scraped rating for movie {i + 1}: {rating}")
        return imdb_ratings


def loop_data():
    imdb_ids = a["imdbId"]
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    try:
        return loop.run_until_complete(loop_data_async(imdb_ids))
    finally:
        loop.close()


a["Imdb_ratings"] = loop_data()
a.head()
# Out:
# Attempt 1/10: Connection error. Retrying...
# Attempt 1/10: Connection error. Retrying...
# Attempt 1/10: Connection error. Retrying...
# Attempt 1/10: Connection error. Retrying...
# Attempt 1/10: Connection error. Retrying...
# Attempt 1/10: Connection error. Retrying...
# Scraped rating for movie 10: 5.9
# Scraped rating for movie 20: 5.6
# Scraped rating for movie 30: 8.1
# Scraped rating for movie 40: 7.0
# Scraped rating for movie 50: 7.2
# Scraped rating for movie 60: 8.3
# Scraped rating for movie 70: 6.8
# Scraped rating for movie 80: 7.3
# Scraped rating for movie 90: 6.0
# Scraped rating for movie 100: 5.2
# Scraped rating for movie 110: 8.3
# Scraped rating for movie 120: 6.6
# Scraped rating for movie 130: 6.7
# Scraped rating for movie 140: 6.7
# Scraped rating for movie 150: 6.1
# Scraped rating for movie 160: 7.3
# Scraped rating for movie 170: 7.4
# Scraped rating for movie 180: 7.7
# Scraped rating for movie 190: 5.6
# Scraped rating for movie 200: 7.6
# ...

# %%
a[a['Imdb_ratings']==a['Imdb_ratings'].max()]
# Out:
#       movieId   imdbId    tmdbId Imdb_ratings
# 8301   106642  2779318  253941.0          9.3
